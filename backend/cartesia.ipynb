# %%
from cartesia import Cartesia
import os
import subprocess
import ffmpeg
import dotenv

dotenv.load_dotenv()

def generate_and_play_audio(transcript, voice_id="a0e99841-438c-4a64-b679-ae501e7d6091", model_id="sonic-english"):
    API_KEY = os.environ.get("CARTESIA_API_KEY")
    print(API_KEY)
    client = Cartesia(api_key=API_KEY)

    output_format = {
        "container": "raw",
        "encoding": "pcm_f32le",
        "sample_rate": 44100,
    }

    # Set up a WebSocket connection.
    ws = client.tts.websocket()

    # Open a file to write the raw PCM audio bytes to.
    with open("sonic.pcm", "wb") as f:
        # Generate and stream audio.
        for output in ws.send(
            model_id=model_id,
            transcript=transcript,
            voice_id=voice_id,
            stream=True,
            output_format=output_format,
        ):
            buffer = output["audio"]  # buffer contains raw PCM audio bytes
            f.write(buffer)

    # Close the connection to release resources
    ws.close()

    # Convert the raw PCM bytes to a WAV file.
    ffmpeg.input("sonic.pcm", format="f32le").output("sonic.wav", **{'y': None}).run()
    # Play the file
    subprocess.run(["ffplay", "-autoexit", "-nodisp", "sonic.wav"])

generate_and_play_audio("Hello! Welcome to Cartesia")
# Out:
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x144a04110] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:02.69, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x144a04380] video:0KiB audio:232KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.032833%
# size=     232KiB time=00:00:02.69 bitrate= 705.8kbits/s speed=1.51e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.69, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
#    2.45 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B
#    2.56 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B

# %%
# set routes for other servers to access this function
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/generate_audio', methods=['POST'])
def generate_audio():
    data = request.json
    print("data", data)
    transcript = data.get('transcript')

    try:
        generate_and_play_audio(transcript)
        return jsonify({"status": "success", "message": "Audio generated and played"}), 200
    except Exception as e:
        return jsonify({"status": "error", "message": str(e)}), 500

if __name__ == '__main__':
    app.run(port=5001)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit
# 127.0.0.1 - - [19/Oct/2024 20:16:31] "POST /generate_audio HTTP/1.1" 400 -
# data {'transcript': 'Hello, this is a test audio generation.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x1318042c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:02.57, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x13072c8b0] video:0KiB audio:221KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.034467%
# size=     221KiB time=00:00:02.56 bitrate= 705.8kbits/s speed=1.67e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.57, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:17:40] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'Hello! Welcome to Cartesia'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x12ef21740] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:02.09, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x12ef222a0] video:0KiB audio:180KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.042318%
# size=     180KiB time=00:00:02.08 bitrate= 705.9kbits/s speed=1.19e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.09, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:18:15] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'Hello, this is a test.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x129f2a4c0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.61, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x129f2aef0] video:0KiB audio:139KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.054800%
# size=     139KiB time=00:00:01.61 bitrate= 706.0kbits/s speed=1e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.61, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:23:26] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'Hello, this is a test.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x12e705340] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.74, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x12e62ce60] video:0KiB audio:150KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.050781%
# size=     150KiB time=00:00:01.74 bitrate= 706.0kbits/s speed=1.01e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.74, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:24:02] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'Current transcript: Hello, how are you, what is your name?'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x122a05be0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:03.19, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x122a06790] video:0KiB audio:275KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.027699%
# size=     275KiB time=00:00:03.19 bitrate= 705.8kbits/s speed=1.88e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.19, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:27] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x141c04190] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:00.98, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x140e1b0a0] video:0KiB audio:84KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.090681%
# size=      84KiB time=00:00:00.97 bitrate= 706.2kbits/s speed= 604x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:00.98, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:42] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x13e305bd0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.24, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x13e306760] video:0KiB audio:107KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.071189%
# size=     107KiB time=00:00:01.24 bitrate= 706.1kbits/s speed=1.11e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.24, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:46] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x11c71fcc0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.13, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x11c7202e0] video:0KiB audio:97KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.078528%
# size=      97KiB time=00:00:01.12 bitrate= 706.2kbits/s speed= 714x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.13, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:49] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x1568051a0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.03, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x156a04160] video:0KiB audio:89KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.085586%
# size=      89KiB time=00:00:01.03 bitrate= 706.2kbits/s speed=1.28e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.03, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:52] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x15810ae50] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.06, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x1580096f0] video:0KiB audio:91KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.083705%
# size=      91KiB time=00:00:01.05 bitrate= 706.2kbits/s speed= 713x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.06, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:56] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x150104670] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.04, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x1501051e0] video:0KiB audio:90KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.084635%
# size=      90KiB time=00:00:01.04 bitrate= 706.2kbits/s speed=1.25e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.04, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:31:59] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'There is nothing new.'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x11f905060] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:00.93, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x11f905960] video:0KiB audio:80KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.095215%
# size=      80KiB time=00:00:00.92 bitrate= 706.3kbits/s speed= 613x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
# ...
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x142f12830] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:00.62, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x142e04310] video:0KiB audio:53KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.143721%
# size=      53KiB time=00:00:00.61 bitrate= 706.6kbits/s speed= 416x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:00.62, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:55:51] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'CRL Hacks 11.0 Aadi'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x13e8205b0] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:02.48, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x13e820fa0] video:0KiB audio:214KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.035594%
# size=     214KiB time=00:00:02.48 bitrate= 705.9kbits/s speed=2.55e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.48, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:55:57] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': "COL Hacks '10"}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x135904080] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:01.46, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x135904cb0] video:0KiB audio:126KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.060454%
# size=     126KiB time=00:00:01.46 bitrate= 706.0kbits/s speed= 868x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.46, bitrate: 706 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:56:02] "POST /generate_audio HTTP/1.1" 200 -
# data {'transcript': 'REFERENCE GUIDE FOR\nGrove Starter Kit Plus\nIoT Edition'}
# f3e31f11-1b9a-445c-ae1d-ebec015f2409
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [f32le @ 0x12b606f60] Estimating duration from bitrate, this may be inaccurate
# Input #0, f32le, from 'sonic.pcm':
#   Duration: 00:00:03.49, bitrate: 1411 kb/s
#   Stream #0:0: Audio: pcm_f32le, 44100 Hz, mono, flt, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_f32le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'sonic.wav':
#   Metadata:
#     ISFT            : Lavf61.7.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s
#       Metadata:
#         encoder         : Lavc61.19.100 pcm_s16le
# [out#0/wav @ 0x12b6072f0] video:0KiB audio:301KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.025306%
# size=     301KiB time=00:00:03.49 bitrate= 705.8kbits/s speed=2.02e+03x
# ffplay version 7.1 Copyright (c) 2003-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, wav, from 'sonic.wav':   0KB vq=    0KB sq=    0B
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.49, bitrate: 705 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 1 channels, s16, 705 kb/s
# 127.0.0.1 - - [19/Oct/2024 20:56:41] "POST /generate_audio HTTP/1.1" 200 -
